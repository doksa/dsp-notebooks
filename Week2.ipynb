# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
import scipy.io.wavfile as wav
from scipy.signal import resample
from IPython.display import Audio
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
T = 1
om0 = 2*np.pi / T
t = np.arange(-T, 3*T, .0005)


fig = plt.figure(figsize=(7, 4))

plt.plot(t, np.sign(np.sin(om0*t)))
# plt.plot(t, 4/np.pi * np.sin(om0*t))
# plt.plot(t, 4/np.pi * (np.sin(om0*t) + 1/3 * np.sin(3*om0*t)))
# plt.plot(t, 4/np.pi * (np.sin(om0*t) + 1/3 * np.sin(3*om0*t) + 1/5 * np.sin(5*om0*t)))

xx = np.zeros(t.shape)If 
for l in range(100):
    xx += 4/np.pi * 1 / (2*l + 1) * np.sin((2*l + 1)*om0*t)
plt.plot(t, xx)


plt.xlim(-.1, 2.1)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
fig = plt.figure(figsize=(7, 15))

om_max = 30
k = np.arange(-100, 100)

ax = fig.add_subplot(411)
T = 2
plt.stem(2*np.pi*k/T, 1/T * np.sinc(k / T))
plt.xlim(-om_max, om_max)

ax = fig.add_subplot(412)
T = 4
plt.stem(2*np.pi*k/T, 1/T * np.sinc(k / T))
plt.xlim(-om_max, om_max)

ax = fig.add_subplot(413)
T = 5
plt.stem(2*np.pi*k/T, 1/T * np.sinc(k / T))
plt.xlim(-om_max, om_max)

ax = fig.add_subplot(414)
T = 10
plt.stem(2*np.pi*k/T, 1/T * np.sinc(k / T))
plt.xlim(-om_max, om_max)
# Out:
# (-30, 30)
